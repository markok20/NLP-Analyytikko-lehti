# %% [markdown]
# # HOW TO ANALYZE SENTIMENT USING VADER

# %% [markdown]
# ## SENTIMENT ANALYSIS
#
# Used to analyze the emotion of the text.
#
# To put it briely, the process of detecting a positive or negative emotion of a text.
#
# Using sentiment analysis we can detect whether the given sentence, paragraph or a document contains a positive or negative emotion/opinion in it.
#
# A tool for the companies to know their customers in-depth.
#
# To know what kind of emotion/sentiment do customers have for them.
#
# Companies can improve their products/services based on the analysis of customer sentiments.
#
# Sentiment analysis of social media data has to be by far the most popular application of NLP on social data.

# %% [markdown]
# ## VADER SENTIMENT TOOL
#
# Stands for Valence Aware Dictionary and Sentiment Reasoner.
#
# More information: https://github.com/markok20/vaderSentiment
#
# A lexicon and rule based tool for sentiment analysis.
#
# Specialized in measuring sentiment in social media.
#
# Used for analyzing the sentiment of text which contains both positive and negative polarity.
#
# The objective is to quantify how much of positive or negative emotion is present in the text.
#
# It can also measure the intensity of emotion.
#
# Open sourced, cost nothing.

# %% [markdown]
# ## ADVANTAGES OF VADER
#
# No requirement of training and testing dataset.
#
# Understands easily the sentiment of a text.
#
# Specialized in measuring sentiment in social media.
#
# Listens to what people are saying about them and their products and services in social media.
#
# Whether people’s opinion is positive or negative and if this sentiment polarity is changing over time.
#
# Easy to use.

# %% [markdown]
# ## CHALLENGES IN GENERAL
#
# Sarcasm.
#
# Some might have both positive and negative opinions.

# %% [markdown]
# ## NLP DATA PIPELINE
#
# Data acquisition
#
# Text cleaning
#
# Pre-processing: tokenization, POS Tagging, removing stopwords, lemmatization
#
# Feature engineering
#
# Modeling
#
# Evaluation
#
# Deployment
#
# Monitoring and model updating

# %% [markdown]
# ## INSTALLING VADER
#
# Install VADER by using the following command
#
# To install this package with conda run:
#
# conda install -c conda-forge vadersentiment

# %% [markdown]
# # Importing libraries

# %%
# Import library

import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Marko\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Import library

from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# # Preparing the sentiment tool and calculating the score

# %%
# Creating Sentiment Intensity Analyzer Object

sentiment = SentimentIntensityAnalyzer()

# %%
# calculating sentiment of a text, positive
# Text is 0.0% Negative, 19.2% Neutral, 80.8% Positive. While the compound score is 63.69%.

sentiment.polarity_scores("I love football.")
# Out:
# {'neg': 0.0, 'neu': 0.192, 'pos': 0.808, 'compound': 0.6369}

# %%
# calculating sentiment, positive
# NOTE: the compound score increases because of capital word & exclamation mark.

print(sentiment.polarity_scores("I LOVE football!!"))
# Out:
# {'neg': 0.0, 'neu': 0.153, 'pos': 0.847, 'compound': 0.7592}

# %%
# calculating sentiment, positive
# NOTE: the compound score increases because of smiley.

print(sentiment.polarity_scores("I love football :)"))
# Out:
# {'neg': 0.0, 'neu': 0.122, 'pos': 0.878, 'compound': 0.802}

# %%
# calculating sentiment, negative
# Text is 78.7% Negative, 21.3% Neutral, 0.0% Positive. While the compound score is -57.19%.

print(sentiment.polarity_scores("I hate football."))
# Out:
# {'neg': 0.787, 'neu': 0.213, 'pos': 0.0, 'compound': -0.5719}

# %%
# calculating sentiment, neutral
# Text is 0.0% Negative, 100.0% Neutral, 0.0% Positive. While the compound score is 0.00%.

print(sentiment.polarity_scores("Marko is a footballer."))
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
# calculating sentiment, border case example 
# Text is 26.2% Negative, 45.2% Neutral, 28.5% Positive. While the compound score is -12.80%.

print(sentiment.polarity_scores("I loved the football game but hated Marko Karttunen. I guess it was a good game."))
# Out:
# {'neg': 0.262, 'neu': 0.452, 'pos': 0.285, 'compound': -0.128}

# %% [markdown]
# ## ABOUT THE SCORING:
#
# SentimentIntensityAnalyzer() is an object.
#
# Polarity_scores is a method which gives us scores of the following categories:
#
# Positive
#
# Negative
#
# Neutral
#
# The more compound score closer to +1, the higher the positivity of the text.
#
# The compound score is computed by summing the valence scores of each word in the lexicon, adjusted according to the rules, and then normalized to be between -1 (most extreme negative) and +1 (most extreme positive).
#
# This is the most useful metric if you want a single unidimensional measure of sentiment for a given sentence. Calling it a normalized, weighted composite score is accurate.
#
# It is also useful for researchers who would like to set standardized thresholds for classifying sentences as either positive, neutral, or negative.
#
# Typical threshold values are:
#
# positive sentiment: compound score >= 0.05
#
# neutral sentiment: (compound score > -0.05) and (compound score < 0.05)
#
# negative sentiment: compound score <= -0.05

# %% [markdown]
# # CASE
#
# Airport service quality Twitter dataset
#
# Measuring the sentiment
#
# 313 376 rows
#
# 13 columns

# %% [markdown]
# # Importing libraries

# %%
# importing libraries

import numpy as np 
import nltk
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# importing libraries

import nltk
nltk.download(['punkt','stopwords'])
from nltk.corpus import stopwords
stopwords = stopwords.words('english')

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Marko\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Marko\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Data in

# %%
# already text preprocessed data in

data = pd.read_csv('newcleaneddata07092021.csv')
data.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1                 Date  \
# 0           0         15421        4/7/2017 7:52
# 1           1         25645      12/3/2018 14:06
# 2           2         88734  12/24/2020 19:34:34
# 3           3        118233   6/23/2017 15:46:40
# 4           4        118234   6/23/2017 15:47:31
# 5           5        181260    6/12/2020 0:33:26
# 6           6        262833    8/29/2020 0:36:32
# 7           7        274014    11/7/2016 6:42:56
# 8           8        274016    11/7/2016 7:01:51
# 9           9        274022   11/7/2016 11:16:36
#
#                                           Tweet Text  Followers  Follows  \
# 0  update flt departed back dublin but flt offloa...    20959.0    240.0
# 1  lads come rally the troops for your pals they ...     1433.0    637.0
# 2                                                NaN    27616.0    868.0
# 3                mike are you scheduled time arrival    37810.0   1849.0
# 4  looks like you will time and will make you sec...    37810.0   1849.0
# 5  june british airways resumed daily service fro...    51130.0   3181.0
# 6                                                NaN    27451.0    452.0
# 7  amazing trip now way home with thx jfk for the...       90.0    318.0
# 8  from brazil get hours there and have nice flig...     1610.0    329.0
# 9                         fast track yeah right slow       93.0    219.0
#
#    Retweets  Favorites Airport_Twitter_Tag Airport_IATA_Codes  \
# 0       0.0        0.0      @dublinairport                DUB
# 1       0.0        0.0      @dublinairport                DUB
# 2       0.0        0.0      @dublinairport                DUB
# 3       0.0        0.0           @schiphol                AMS
# 4       0.0        0.0           @schiphol                AMS
# 5       0.0        0.0    @heathrowairport                LHR
# 6       0.0        2.0    @heathrowairport                LHR
# 7       0.0        0.0    @heathrowairport                LHR
# 8       0.0        0.0    @heathrowairport                LHR
# 9       0.0        0.0      @dublinairport                DUB
#
#                 Airport_Names  \
# 0              Dublin Airport
# 1              Dublin Airport
# 2              Dublin Airport
# 3  Amsterdam Airport Schiphol
# 4  Amsterdam Airport Schiphol
# 5            Heathrow Airport
# 6            Heathrow Airport
# 7            Heathrow Airport
# 8            Heathrow Airport
# 9              Dublin Airport
#
#                                               tokens  \
# 0  ['update', 'flt', 'departed', 'back', 'dublin'...
# 1  ['lads', 'come', 'rally', 'troops', 'pals', 'a...
# 2                                                 []
# 3           ['mike', 'scheduled', 'time', 'arrival']
# 4  ['looks', 'like', 'time', 'make', 'second', 'f...
# 5  ['june', 'british', 'airways', 'resumed', 'dai...
# 6                                                 []
# 7  ['amazing', 'trip', 'way', 'home', 'thx', 'jfk...
# 8  ['brazil', 'get', 'hours', 'nice', 'flight', '...
# 9         ['fast', 'track', 'yeah', 'right', 'slow']
#
#                                            no_tokens
# 0  ['update', 'flt', 'departed', 'back', 'dublin'...
# 1  ['lads', 'come', 'rally', 'troops', 'pals', 'a...
# 2                                                 []
# 3           ['mike', 'scheduled', 'time', 'arrival']
# 4  ['looks', 'like', 'time', 'make', 'second', 'f...
# 5  ['june', 'british', 'airways', 'resumed', 'dai...
# 6                                                 []
# 7  ['amazing', 'trip', 'way', 'home', 'thx', 'jfk...
# 8  ['brazil', 'get', 'hours', 'nice', 'flight', '...
# 9         ['fast', 'track', 'yeah', 'right', 'slow']

# %%
# Checking data

# 313 376 rows

# 13 columns

data.shape
# Out:
# (313376, 13)

# %%
# checking null values

data.isnull().any().any()
# Out:
# True

# %%
# checking null values

data.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313376 entries, 0 to 313375
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           313376 non-null  int64
#  1   Unnamed: 0.1         313376 non-null  int64
#  2   Date                 313376 non-null  object
#  3   Tweet Text           278312 non-null  object
#  4   Followers            313376 non-null  float64
#  5   Follows              313376 non-null  float64
#  6   Retweets             313376 non-null  float64
#  7   Favorites            313376 non-null  float64
#  8   Airport_Twitter_Tag  313376 non-null  object
#  9   Airport_IATA_Codes   313376 non-null  object
#  10  Airport_Names        313376 non-null  object
#  11  tokens               313376 non-null  object
#  12  no_tokens            313376 non-null  object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 31.1+ MB
# <ipython-input-27-26593ddadbbc>:3: FutureWarning: null_counts is deprecated. Use show_counts instead
#   data.info(null_counts=True)

# %%
# checking null values

data_new = data[data['Tweet Text'].notnull()]

# %%
# checking null values

data_new.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 278312 entries, 0 to 313375
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           278312 non-null  int64
#  1   Unnamed: 0.1         278312 non-null  int64
#  2   Date                 278312 non-null  object
#  3   Tweet Text           278312 non-null  object
#  4   Followers            278312 non-null  float64
#  5   Follows              278312 non-null  float64
#  6   Retweets             278312 non-null  float64
#  7   Favorites            278312 non-null  float64
#  8   Airport_Twitter_Tag  278312 non-null  object
#  9   Airport_IATA_Codes   278312 non-null  object
#  10  Airport_Names        278312 non-null  object
#  11  tokens               278312 non-null  object
#  12  no_tokens            278312 non-null  object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 29.7+ MB
# <ipython-input-29-6fc42301145a>:3: FutureWarning: null_counts is deprecated. Use show_counts instead
#   data_new.info(null_counts=True)

# %%
# checking null values

data_new.isnull().any().any()
# Out:
# False

# %% [markdown]
# # Calculating score and labeling the data

# %%
# calculating compound score and labeling vader score

data_new['vader_score'] = data_new['Tweet Text'].apply(lambda x: analyzer.polarity_scores(x)['compound'])
# Out:
# C:\Users\Marko\anaconda3\envs\Karttunen\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
# checking data and vader score column

data_new.head(15)
# Out:
#     Unnamed: 0  Unnamed: 0.1                Date  \
# 0            0         15421       4/7/2017 7:52
# 1            1         25645     12/3/2018 14:06
# 3            3        118233  6/23/2017 15:46:40
# 4            4        118234  6/23/2017 15:47:31
# 5            5        181260   6/12/2020 0:33:26
# 7            7        274014   11/7/2016 6:42:56
# 8            8        274016   11/7/2016 7:01:51
# 9            9        274022  11/7/2016 11:16:36
# 10          10        274023  11/7/2016 12:23:15
# 11          11        274024  11/7/2016 12:26:07
# 12          12        274027  11/7/2016 12:48:59
# 13          13        274028  11/7/2016 12:59:00
# 14          14        274029  11/7/2016 13:03:51
# 15          15        274030  11/7/2016 13:20:50
# 16          16        274032  11/7/2016 13:47:49
#
#                                            Tweet Text  Followers  Follows  \
# 0   update flt departed back dublin but flt offloa...    20959.0    240.0
# 1   lads come rally the troops for your pals they ...     1433.0    637.0
# 3                 mike are you scheduled time arrival    37810.0   1849.0
# 4   looks like you will time and will make you sec...    37810.0   1849.0
# 5   june british airways resumed daily service fro...    51130.0   3181.0
# 7   amazing trip now way home with thx jfk for the...       90.0    318.0
# 8   from brazil get hours there and have nice flig...     1610.0    329.0
# 9                          fast track yeah right slow       93.0    219.0
# 10  what with drop off lanes terminal the queue re...      358.0    379.0
# 11                                             landan      195.0   1118.0
# 12                               beautiful copenhagen       48.0    199.0
# 13  you need sort out your doors arrivals the nort...      134.0    792.0
# 14  you seem miss the point flight connection shou...      274.0    583.0
# 15                                 work unfortunately      189.0    652.0
# 16                                    thank you sarah      880.0    858.0
#
#     Retweets  Favorites Airport_Twitter_Tag Airport_IATA_Codes  \
# 0        0.0        0.0      @dublinairport                DUB
# 1        0.0        0.0      @dublinairport                DUB
# 3        0.0        0.0           @schiphol                AMS
# 4        0.0        0.0           @schiphol                AMS
# 5        0.0        0.0    @heathrowairport                LHR
# 7        0.0        0.0    @heathrowairport                LHR
# 8        0.0        0.0    @heathrowairport                LHR
# 9        0.0        0.0      @dublinairport                DUB
# 10       0.0        0.0    @heathrowairport                LHR
# 11       0.0        0.0    @gatwick_airport                LGW
# 12       0.0        0.0    @gatwick_airport                LGW
# 13       0.0        0.0    @gatwick_airport                LGW
# 14       0.0        0.0    @heathrowairport                LHR
# 15       0.0        0.0    @heathrowairport                LHR
# 16       0.0        0.0    @gatwick_airport                LGW
#
#                  Airport_Names  \
# 0               Dublin Airport
# 1               Dublin Airport
# 3   Amsterdam Airport Schiphol
# 4   Amsterdam Airport Schiphol
# 5             Heathrow Airport
# 7             Heathrow Airport
# 8             Heathrow Airport
# 9               Dublin Airport
# 10            Heathrow Airport
# 11         Gatwick Airport LGW
# 12         Gatwick Airport LGW
# 13         Gatwick Airport LGW
# 14            Heathrow Airport
# 15            Heathrow Airport
# 16         Gatwick Airport LGW
#
#                                                tokens  \
# 0   ['update', 'flt', 'departed', 'back', 'dublin'...
# 1   ['lads', 'come', 'rally', 'troops', 'pals', 'a...
# 3            ['mike', 'scheduled', 'time', 'arrival']
# 4   ['looks', 'like', 'time', 'make', 'second', 'f...
# 5   ['june', 'british', 'airways', 'resumed', 'dai...
# 7   ['amazing', 'trip', 'way', 'home', 'thx', 'jfk...
# 8   ['brazil', 'get', 'hours', 'nice', 'flight', '...
# 9          ['fast', 'track', 'yeah', 'right', 'slow']
# 10  ['drop', 'lanes', 'terminal', 'queue', 'reache...
# 11                                         ['landan']
# 12                        ['beautiful', 'copenhagen']
# 13  ['need', 'sort', 'doors', 'arrivals', 'north',...
# 14  ['seem', 'miss', 'point', 'flight', 'connectio...
# 15                          ['work', 'unfortunately']
# 16                                 ['thank', 'sarah']
#
#                                             no_tokens  vader_score
# 0   ['update', 'flt', 'departed', 'back', 'dublin'...       0.0000
# 1   ['lads', 'come', 'rally', 'troops', 'pals', 'a...       0.0000
# 3            ['mike', 'scheduled', 'time', 'arrival']       0.0000
# 4   ['looks', 'like', 'time', 'make', 'second', 'f...       0.6597
# 5   ['june', 'british', 'airways', 'resumed', 'dai...       0.0000
# 7   ['amazing', 'trip', 'way', 'home', 'thx', 'jfk...       0.8860
# 8   ['brazil', 'get', 'hours', 'nice', 'flight', '...      -0.0258
# 9          ['fast', 'track', 'yeah', 'right', 'slow']       0.2960
# 10  ['drop', 'lanes', 'terminal', 'queue', 'reache...      -0.2263
# 11                                         ['landan']       0.0000
# 12                        ['beautiful', 'copenhagen']       0.5994
# 13  ['need', 'sort', 'doors', 'arrivals', 'north',...       0.0762
# 14  ['seem', 'miss', 'point', 'flight', 'connectio...      -0.1531
# 15                          ['work', 'unfortunately']      -0.3400
# 16                                 ['thank', 'sarah']       0.3612

# %%
# checking positive and negative

positive_num = len(data_new[data_new['vader_score'] >=0.05])

negative_num = len(data_new[data_new['vader_score']<0.05])

# %%
# checking positive and negative

#positive_num,neutral_num, negative_num
positive_num, negative_num
# Out:
# (120013, 158299)

# %%
# adding vader sentiment label column

data_new['vader_sentiment_label']= data_new['vader_score'].map(lambda x:int(1) if x>=0.05 else int(0))
# Out:
# C:\Users\Marko\anaconda3\envs\Karttunen\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
# adding vader sentiment label column

#data_new.loc[df_new['vaderReviewScore'] >=0.00,"vaderSentimentLabel"] = 1
#data_new.loc[df_new['vaderReviewScore']<=-0.00,"vaderSentimentLabel"] = 0

# checking vader sentiment label column

data_new.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                Date  \
# 0           0         15421       4/7/2017 7:52
# 1           1         25645     12/3/2018 14:06
# 3           3        118233  6/23/2017 15:46:40
# 4           4        118234  6/23/2017 15:47:31
# 5           5        181260   6/12/2020 0:33:26
#
#                                           Tweet Text  Followers  Follows  \
# 0  update flt departed back dublin but flt offloa...    20959.0    240.0
# 1  lads come rally the troops for your pals they ...     1433.0    637.0
# 3                mike are you scheduled time arrival    37810.0   1849.0
# 4  looks like you will time and will make you sec...    37810.0   1849.0
# 5  june british airways resumed daily service fro...    51130.0   3181.0
#
#    Retweets  Favorites Airport_Twitter_Tag Airport_IATA_Codes  \
# 0       0.0        0.0      @dublinairport                DUB
# 1       0.0        0.0      @dublinairport                DUB
# 3       0.0        0.0           @schiphol                AMS
# 4       0.0        0.0           @schiphol                AMS
# 5       0.0        0.0    @heathrowairport                LHR
#
#                 Airport_Names  \
# 0              Dublin Airport
# 1              Dublin Airport
# 3  Amsterdam Airport Schiphol
# 4  Amsterdam Airport Schiphol
# 5            Heathrow Airport
#
#                                               tokens  \
# 0  ['update', 'flt', 'departed', 'back', 'dublin'...
# 1  ['lads', 'come', 'rally', 'troops', 'pals', 'a...
# 3           ['mike', 'scheduled', 'time', 'arrival']
# 4  ['looks', 'like', 'time', 'make', 'second', 'f...
# 5  ['june', 'british', 'airways', 'resumed', 'dai...
#
#                                            no_tokens  vader_score  \
# 0  ['update', 'flt', 'departed', 'back', 'dublin'...       0.0000
# 1  ['lads', 'come', 'rally', 'troops', 'pals', 'a...       0.0000
# 3           ['mike', 'scheduled', 'time', 'arrival']       0.0000
# 4  ['looks', 'like', 'time', 'make', 'second', 'f...       0.6597
# 5  ['june', 'british', 'airways', 'resumed', 'dai...       0.0000
#
#    vader_sentiment_label
# 0                      0
# 1                      0
# 3                      0
# 4                      1
# 5                      0

# %%
# checking positive, neutral and negative

positive_num = len(data_new[data_new['vader_score'] >=0.05])
neutral_num = len(data_new[(data_new['vader_score'] >-0.05) & (data_new['vader_score']<0.05)])
negative_num = len(data_new[data_new['vader_score']<=-0.05])

# %%
# checking positive, neutral and negative

positive_num,neutral_num, negative_num
# Out:
# (120013, 112398, 45901)

# %% [markdown]
# # Examples how to illustrate the sentiment

# %%
# all tokens illustrated in wordcloud but negative sentiment
# time, security, gate, bus, baggege, luggage, stuck, bag, car parking, passport control, staff

normal_words =' '.join([text for text in data_new['no_tokens'][data_new['vader_sentiment_label'] == 0]])

from wordcloud import WordCloud
wordcloud = WordCloud(width=800, background_color='white', height=500, random_state=21, max_font_size=110).generate(normal_words)
plt.figure(figsize=(12, 12))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# # Example of Sentiment Intensity
#
# Here you can make observations how the sentiment has developed during the selected period of time and make decisions what to do next in your analysis for instance to explore what is the reason behind the negative sentiment.

# %%
# Convert the data column to pandas datetime

data_new['Date'] = pd.to_datetime(data['Date']).dt.date

# %%
# Setting up the data ready for Sentiment Intensity 

# Plotting a bar chart to visualize our sentiments.
# LHR    0.102629
# MAN    0.083148
# DUB    0.064212
# LGW    0.053382
# STN    0.045671

period = 100

mean_df = data_new.groupby(['Airport_IATA_Codes','Date']).mean().unstack().xs('vader_score', axis='columns').transpose()
mean_df = mean_df.iloc[-period:]

# %%
# Plot a bar chart to visualize our sentiments.
# LHR    0.102629

plt.figure(figsize=(15,8))

plt.bar(mean_df.index,mean_df.LHR , label='LHR') 

plt.title('Sentiment Intensity Chart')
plt.xlabel('Days over the past 100 days period')
plt.ylabel('Sentiment Intensity')
plt.legend()

plt.show()

# %%
# Plot a bar chart to visualize our sentiments.
# MAN    0.083148

plt.figure(figsize=(15,8))

plt.bar(mean_df.index,mean_df.MAN, label='MAN')

plt.title('Sentiment Intensity Chart')
plt.xlabel('Days over the past 100 days period')
plt.ylabel('Sentiment Intensity')
plt.legend()

plt.show()

# %%
# Plot a bar chart to visualize our sentiments.

# DUB    0.064212


plt.figure(figsize=(15,8))

plt.bar(mean_df.index,mean_df.DUB, label='DUB')

plt.title('Sentiment Intensity Chart')
plt.xlabel('Days over the past 100 days period')
plt.ylabel('Sentiment Intensity')
plt.legend()

plt.show()

# %%
# Plot a bar chart to visualize our sentiments.

# LGW    0.053382


plt.figure(figsize=(15,8))

plt.bar(mean_df.index,mean_df.LGW, label='LGW')

plt.title('Sentiment Intensity Chart')
plt.xlabel('Days over the past 100 days period')
plt.ylabel('Sentiment Intensity')
plt.legend()

plt.show()

# %%
# Plot a bar chart to visualize our sentiments.

# STN    0.045671

plt.figure(figsize=(15,8))

plt.bar(mean_df.index,mean_df.STN, label='STN')

plt.title('Sentiment Intensity Chart')
plt.xlabel('Days over the past 100 days period')
plt.ylabel('Sentiment Intensity')
plt.legend()

plt.show()

# %%
# Plot a bar chart to visualize our sentiments.

# LHR    0.102629
# MAN    0.083148
# DUB    0.064212
# LGW    0.053382
# STN    0.045671

plt.figure(figsize=(15,8))

plt.bar(mean_df.index,mean_df.LHR , label='LHR') 
plt.bar(mean_df.index,mean_df.MAN, label='MAN')
plt.bar(mean_df.index,mean_df.DUB, label='DUB')
plt.bar(mean_df.index,mean_df.LGW, label='LGW')
plt.bar(mean_df.index,mean_df.STN, label='STN')

plt.title('Sentiment Intensity Chart')
plt.xlabel('Days over the past 100 days period')
plt.ylabel('Sentiment Intensity')
plt.legend()

plt.show()
